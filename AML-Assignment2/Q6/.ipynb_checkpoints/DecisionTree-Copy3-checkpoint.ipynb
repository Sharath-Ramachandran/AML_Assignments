# %%
# CS6510 HW 1 Code Skeleton
# Please use this outline to implement your decision tree. You can add any code around this.
import csv
import math
import numpy as np
# Enter You Name Here
myname = "Doe-John-Sharath" # or "Doe-Jane-"

# %%
def entropyFun(training_set, column_index, value):
    #print(float(training_set[0][-1]))
    col_data_1= [float(row[column_index]) for row in training_set if float(row[-1])==1]
    col_data_2= [float(row[column_index]) for row in training_set if float(row[-1])==0]

    count_positive_list1= [row for row in col_data_1 if row>= value]
    count_positive_class1= len(count_positive_list1)
    count_negative_class1= len(col_data_1)- count_positive_class1
    
    count_positive_list2= [row for row in col_data_2 if row>= value]
    count_positive_class2= len(count_positive_list2)
    count_negative_class2= len(col_data_2)- count_positive_class2
    
    count_greater= count_positive_class1 + count_positive_class2
    count_lesser = count_negative_class1 + count_negative_class2

    
    prob_greater = float(count_greater/(count_greater+count_lesser))
    prob_lesser = 1- prob_greater

    temp1=1
    temp=1
    if(count_greater>0):
        temp = float(count_positive_class1/ count_greater)
    if(count_lesser>0): 
        temp1 = float(count_negative_class1/ count_lesser)
        
        
#     print(prob_greater)
#     print(prob_lesser)
#     print(temp)
#     print(temp1) 
    if((temp ==0 or temp ==1) and (temp1==0 or temp1==1)):
        entropy_val=0
    elif(temp ==0 or temp==1):
        entropy_val= prob_lesser*(-(temp1*math.log(temp1,2) + (1-temp1)*math.log((1-temp1),2)))
    elif(temp1== 0 or temp1==1):
        entropy_val= prob_greater*(-(temp*math.log(temp,2) + (1-temp)*math.log((1-temp),2)))
    else:
        entropy_val=float((prob_greater*(-(temp*math.log(temp,2) + (1-temp)*math.log((1-temp),2)))+prob_lesser*(-(temp1*math.log(temp1,2) + (1-temp1)*math.log((1-temp1),2)))))
    return entropy_val

# %%
def findSplit(training_set,entropy):
    local_entropy=0
    local_column=None
    best_entropy=1
    best_column=None
    col_mean_final=0
    '''if entropy==2:
        entropy= calculateInitialEntropy(training_set)
    '''
    for col in range(0,len(training_set[0])-1):
        
        col_data= [float(row[col]) for row in training_set]
        col_mean=float(np.sum(col_data)/len(col_data))
        
        local_entropy= entropyFun(training_set,col,col_mean)
        #print("Local entropy for column ",col," is", local_entropy," with value ",col_mean)
        
        if local_entropy< best_entropy:  
            best_entropy=local_entropy
            best_column = col
            col_mean_final=col_mean

    
    return  best_entropy,best_column,col_mean_final

# %%
def partition(training_set, column_index, value):
    true_rows= [row for row in training_set if float(row[column_index]) >= value]
    false_rows = [row for row in training_set if float(row[column_index])< value]
    return true_rows, false_rows

# %%
'''def calculateInitialEntropy(training_set):
    col_data_1= len([row for row in training_set if float(row[-1])==1])
    col_data_2= len([row for row in training_set if float(row[-1])==0])
    prob_col_data_1= float(col_data_1/(col_data_2+col_data_1))
    entropy= -(prob_col_data_1*math.log(prob_col_data_1,2) + (1-prob_col_data_1)*(math.log((1-prob_col_data_1),2)))
    return entropy'''
# Out:
# 'def calculateInitialEntropy(training_set):\n    col_data_1= len([row for row in training_set if float(row[-1])==1])\n    col_data_2= len([row for row in training_set if float(row[-1])==0])\n    prob_col_data_1= float(col_data_1/(col_data_2+col_data_1))\n    entropy= -(prob_col_data_1*math.log(prob_col_data_1,2) + (1-prob_col_data_1)*(math.log((1-prob_col_data_1),2)))\n    return entropy'

# %%
def getClass(training_set, column_index,value):
    true_label= None
    false_label=None
    true_rows= [row for row in training_set if float(row[column_index]) >= value]
    false_rows = [row for row in training_set if float(row[column_index])< value]
    if len(true_rows)>0:
        true_label = true_rows[0][-1]
    if len(false_rows)>0:
        false_label= false_rows[0][-1]
    print(type(false_label))
    print(type(true_label))
    if false_label=="1":
        false_label="class1"
    if true_label=="0":
        true_label="class0"
    if false_label=="0":
        false_label="class0"
    if true_label=="1":
        true_label="class1"
    print("For column ",column_index," with value",value ,"we have the true and false labels as",true_label, false_label)
    return true_label,false_label

# %%
class DecisionTree():
    tree = {}

    def learn(self, training_set,index, entropy):
        #implement this function
        value=0
        true_index=0
        false_index=0
        entropy,column_name,value = findSplit(training_set,entropy)
        #print("Entropy of column ",column_name," is ",entropy)
        #check terminating criteria
        if entropy==0:
            print("Base case for index ",index," column ",column_name)
            return getClass(training_set, column_name, value)
        # get the true and false rows based on the criteria
        true_rows, false_rows = partition(training_set,column_name,value)
        
        
        print("True rows of col ",column_name, "of index ",index)
        #print(true_rows)
        true_index= self.learn(true_rows, 2*index,entropy)
        
        print("false rows of col ",column_name," of index ",index)
        false_index= self.learn(false_rows,2*index+1, entropy)
        
        #print("True_Index for index ", index,true_index)
        #print("False_Index for index ",index, false_index)
        
        self.tree[index]=[column_name,value,{"true_rows":true_index,"false_rows":false_index}]
        return index
    #implement this function


    def classify(self, test_instance):
        result = 0 # baseline: always classifies as 0
        #print(self.tree)
        print(self.tree)
        return result

# %%
def run_decision_tree():

    # Load data set
    with open("assign1-q1-data.csv") as f:
        next(f, None)
        data = [tuple(line) for line in csv.reader(f, delimiter=",")]
    print("Number of records: %d" % len(data))

    # Split training/test sets
    # You need to modify the following code for cross validation.
    K = 10
    training_set = [x for i, x in enumerate(data) if i % K != 9]
    test_set = [x for i, x in enumerate(data) if i % K == 9]
    
    columns_set={}
    tree = DecisionTree()
    # Construct a tree using training set
    tree.learn( training_set,1,2)
    #print(tree)
    # Classify the test set using the tree we just constructed
    results = []
    #for instance in test_set:
        #result = tree.classify( instance[:-1] ) # prints all values except the last one
        #results.append( result == instance[-1])
    tree.classify(training_set)
    # Accuracy
    #accuracy = float(results.count(True))/float(len(results))
    #print("accuracy: %.4f" % accuracy)       
    

    # Writing results to a file (DO NOT CHANGE)
    #f = open(myname+"result.txt", "w")
    #f.write("accuracy: %.4f" % accuracy)
    #f.close()

# %%
if __name__ == "__main__":
    run_decision_tree()
# Out:
# Number of records: 4898
# True rows of col  10 of index  1
# True rows of col  10 of index  2
# True rows of col  10 of index  4
# True rows of col  5 of index  8
# True rows of col  9 of index  16
# True rows of col  8 of index  32
# True rows of col  1 of index  64
# True rows of col  4 of index  128
# Base case for index  256  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.033333333333334 we have the true and false labels as class1 class1
# false rows of col  4  of index  128
# Base case for index  257  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.26 we have the true and false labels as class1 class0
# false rows of col  1  of index  64
# True rows of col  2 of index  129
# True rows of col  3 of index  258
# Base case for index  516  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.2 we have the true and false labels as class1 class0
# false rows of col  3  of index  258
# Base case for index  517  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.375 we have the true and false labels as class0 class0
# false rows of col  2  of index  129
# True rows of col  8 of index  259
# True rows of col  2 of index  518
# Base case for index  1036  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.159999999999999 we have the true and false labels as class1 class1
# false rows of col  2  of index  518
# Base case for index  1037  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.766666666666667 we have the true and false labels as class1 class0
# false rows of col  8  of index  259
# True rows of col  8 of index  519
# Base case for index  1038  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.0249999999999995 we have the true and false labels as class0 class0
# false rows of col  8  of index  519
# True rows of col  0 of index  1039
# Base case for index  2078  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.933333333333334 we have the true and false labels as class1 class0
# false rows of col  0  of index  1039
# Base case for index  2079  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.5 we have the true and false labels as class1 class1
# false rows of col  8  of index  32
# True rows of col  6 of index  65
# True rows of col  8 of index  130
# True rows of col  0 of index  260
# True rows of col  1 of index  520
# Base case for index  1040  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.15 we have the true and false labels as class1 class0
# false rows of col  1  of index  520
# Base case for index  1041  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.75 we have the true and false labels as class0 class0
# false rows of col  0  of index  260
# Base case for index  521  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.666666666666667 we have the true and false labels as class1 class1
# false rows of col  8  of index  130
# Base case for index  261  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.8999999999999995 we have the true and false labels as class1 class1
# false rows of col  6  of index  65
# True rows of col  2 of index  131
# True rows of col  6 of index  262
# Base case for index  524  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.183333333333334 we have the true and false labels as class1 class1
# false rows of col  6  of index  262
# True rows of col  0 of index  525
# Base case for index  1050  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.65 we have the true and false labels as class1 class1
# false rows of col  0  of index  525
# Base case for index  1051  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.1 we have the true and false labels as class1 class0
# false rows of col  2  of index  131
# Base case for index  263  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.246666666666668 we have the true and false labels as class1 class1
# false rows of col  9  of index  16
# True rows of col  6 of index  33
# True rows of col  4 of index  66
# True rows of col  9 of index  132
# True rows of col  7 of index  264
# Base case for index  528  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.325 we have the true and false labels as class1 class1
# false rows of col  7  of index  264
# True rows of col  2 of index  529
# Base case for index  1058  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 7.6 we have the true and false labels as class0 None
# false rows of col  2  of index  529
# True rows of col  7 of index  1059
# True rows of col  0 of index  2118
# Base case for index  4236  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.7 we have the true and false labels as class1 class0
# false rows of col  0  of index  2118
# Base case for index  4237  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 6.0 we have the true and false labels as class0 None
# false rows of col  7  of index  1059
# Base case for index  2119  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.433333333333334 we have the true and false labels as class1 class1
# false rows of col  9  of index  132
# True rows of col  4 of index  265
# Base case for index  530  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.716666666666666 we have the true and false labels as class0 class0
# false rows of col  4  of index  265
# Base case for index  531  column  7
# <class 'str'>
# <class 'str'>
# For column  7  with value 0.9898725 we have the true and false labels as class0 class1
# false rows of col  4  of index  66
# True rows of col  9 of index  133
# True rows of col  2 of index  266
# True rows of col  0 of index  532
# Base case for index  1064  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.325000000000001 we have the true and false labels as class1 class1
# false rows of col  0  of index  532
# Base case for index  1065  column  9
# <class 'str'>
# <class 'str'>
# For column  9  with value 0.41 we have the true and false labels as class0 class1
# false rows of col  2  of index  266
# Base case for index  533  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.211111111111111 we have the true and false labels as class1 class1
# false rows of col  9  of index  133
# Base case for index  267  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.01 we have the true and false labels as class1 class1
# false rows of col  6  of index  33
# True rows of col  3 of index  67
# True rows of col  6 of index  134
# True rows of col  4 of index  268
# Base case for index  536  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.566666666666667 we have the true and false labels as class0 class0
# false rows of col  4  of index  268
# Base case for index  537  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.2 we have the true and false labels as class0 class1
# false rows of col  6  of index  134
# Base case for index  269  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.042857142857143 we have the true and false labels as class1 class1
# false rows of col  3  of index  67
# True rows of col  7 of index  135
# True rows of col  0 of index  270
# True rows of col  0 of index  540
# Base case for index  1080  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.75 we have the true and false labels as class0 class0
# false rows of col  0  of index  540
# True rows of col  0 of index  1081
# Base case for index  2162  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.32666666666666666 we have the true and false labels as class0 class1
# false rows of col  0  of index  1081
# Base case for index  2163  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 7.099999999999999 we have the true and false labels as class1 None
# false rows of col  0  of index  270
# True rows of col  1 of index  541
# Base case for index  1082  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.414285714285714 we have the true and false labels as class0 class0
# false rows of col  1  of index  541
# Base case for index  1083  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.775 we have the true and false labels as class0 class1
# false rows of col  7  of index  135
# True rows of col  0 of index  271
# True rows of col  2 of index  542
# True rows of col  0 of index  1084
# Base case for index  2168  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.30500000000000005 we have the true and false labels as class1 class0
# false rows of col  0  of index  1084
# Base case for index  2169  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.15 we have the true and false labels as class0 class0
# false rows of col  2  of index  542
# Base case for index  1085  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.542857142857144 we have the true and false labels as class1 class1
# false rows of col  0  of index  271
# True rows of col  3 of index  543
# Base case for index  1086  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.3 we have the true and false labels as class1 class0
# false rows of col  3  of index  543
# Base case for index  1087  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.766666666666667 we have the true and false labels as class0 class0
# false rows of col  5  of index  8
# True rows of col  5 of index  17
# True rows of col  3 of index  34
# True rows of col  2 of index  68
# True rows of col  1 of index  136
# Base case for index  272  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.283333333333332 we have the true and false labels as class1 class1
# false rows of col  1  of index  136
# True rows of col  8 of index  273
# Base case for index  546  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.528571428571429 we have the true and false labels as class1 class1
# false rows of col  8  of index  273
# Base case for index  547  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.27166666666666667 we have the true and false labels as class1 class0
# false rows of col  2  of index  68
# True rows of col  7 of index  137
# True rows of col  3 of index  274
# Base case for index  548  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.959999999999999 we have the true and false labels as class0 class0
# false rows of col  3  of index  274
# Base case for index  549  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.4033333333333333 we have the true and false labels as class0 class1
# false rows of col  7  of index  137
# True rows of col  0 of index  275
# Base case for index  550  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.628571428571428 we have the true and false labels as class1 class1
# false rows of col  0  of index  275
# Base case for index  551  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.875 we have the true and false labels as class1 class0
# false rows of col  3  of index  34
# True rows of col  4 of index  69
# True rows of col  3 of index  138
# True rows of col  5 of index  276
# True rows of col  3 of index  552
# Base case for index  1104  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.3999999999999995 we have the true and false labels as class0 class0
# false rows of col  3  of index  552
# Base case for index  1105  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.3233333333333333 we have the true and false labels as class0 class1
# false rows of col  5  of index  276
# Base case for index  553  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.0249999999999995 we have the true and false labels as class1 class1
# false rows of col  3  of index  138
# Base case for index  277  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.872727272727272 we have the true and false labels as class0 class0
# false rows of col  4  of index  69
# True rows of col  1 of index  139
# True rows of col  3 of index  278
# True rows of col  0 of index  556
# Base case for index  1112  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.26 we have the true and false labels as class0 class1
# false rows of col  0  of index  556
# Base case for index  1113  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.25 we have the true and false labels as class0 class0
# false rows of col  3  of index  278
# Base case for index  557  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.418181818181818 we have the true and false labels as class1 class1
# false rows of col  1  of index  139
# True rows of col  10 of index  279
# True rows of col  0 of index  558
# True rows of col  2 of index  1116
# Base case for index  2232  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 26.666666666666668 we have the true and false labels as class1 class0
# false rows of col  2  of index  1116
# Base case for index  2233  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.0 we have the true and false labels as class0 class0
# false rows of col  0  of index  558
# Base case for index  1117  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.375 we have the true and false labels as class1 class1
# false rows of col  10  of index  279
# True rows of col  3 of index  559
# Base case for index  1118  column  8
# <class 'str'>
# <class 'str'>
# For column  8  with value 3.1522222222222225 we have the true and false labels as class1 class0
# false rows of col  3  of index  559
# True rows of col  7 of index  1119
# Base case for index  2238  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.9399999999999995 we have the true and false labels as class0 class0
# false rows of col  7  of index  1119
# Base case for index  2239  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.75 we have the true and false labels as class0 class1
# false rows of col  5  of index  17
# True rows of col  0 of index  35
# True rows of col  8 of index  70
# True rows of col  4 of index  140
# True rows of col  7 of index  280
# True rows of col  2 of index  560
# Base case for index  1120  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.639999999999999 we have the true and false labels as class0 class0
# false rows of col  2  of index  560
# Base case for index  1121  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.21666666666666667 we have the true and false labels as class1 class0
# false rows of col  7  of index  280
# True rows of col  2 of index  561
# Base case for index  1122  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.833333333333333 we have the true and false labels as class1 class1
# false rows of col  2  of index  561
# Base case for index  1123  column  4
# <class 'str'>
# <class 'str'>
# For column  4  with value 0.044 we have the true and false labels as class1 class0
# false rows of col  4  of index  140
# True rows of col  3 of index  281
# True rows of col  10 of index  562
# Base case for index  1124  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.65 we have the true and false labels as class1 class1
# false rows of col  10  of index  562
# True rows of col  0 of index  1125
# Base case for index  2250  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.35 we have the true and false labels as class1 class0
# false rows of col  0  of index  1125
# Base case for index  2251  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.6499999999999995 we have the true and false labels as class0 class0
# false rows of col  3  of index  281
# True rows of col  3 of index  563
# Base case for index  1126  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.38000000000000006 we have the true and false labels as class0 class1
# false rows of col  3  of index  563
# Base case for index  1127  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.675 we have the true and false labels as class0 class0
# false rows of col  8  of index  70
# True rows of col  9 of index  141
# Base case for index  282  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.235714285714285 we have the true and false labels as class0 class0
# false rows of col  9  of index  141
# True rows of col  4 of index  283
# Base case for index  566  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.233333333333334 we have the true and false labels as class0 class0
# false rows of col  4  of index  283
# True rows of col  2 of index  567
# Base case for index  1134  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 8.8 we have the true and false labels as class1 None
# false rows of col  2  of index  567
# True rows of col  2 of index  1135
# Base case for index  2270  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.260000000000001 we have the true and false labels as class0 class0
# false rows of col  2  of index  1135
# Base case for index  2271  column  8
# <class 'str'>
# <class 'str'>
# For column  8  with value 3.116666666666667 we have the true and false labels as class1 class0
# false rows of col  0  of index  35
# True rows of col  7 of index  71
# True rows of col  4 of index  142
# True rows of col  7 of index  284
# Base case for index  568  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.8500000000000005 we have the true and false labels as class1 class1
# false rows of col  7  of index  284
# Base case for index  569  column  10
# <class 'str'>
# <class 'str'>
# For column  10  with value 12.9 we have the true and false labels as class1 class0
# false rows of col  4  of index  142
# True rows of col  1 of index  285
# Base case for index  570  column  7
# <class 'str'>
# <class 'str'>
# For column  7  with value 0.9918833333333333 we have the true and false labels as class0 class1
# false rows of col  1  of index  285
# Base case for index  571  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.25 we have the true and false labels as class0 class0
# false rows of col  7  of index  71
# True rows of col  5 of index  143
# True rows of col  1 of index  286
# Base case for index  572  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.71 we have the true and false labels as class1 class1
# false rows of col  1  of index  286
# True rows of col  9 of index  573
# Base case for index  1146  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.05 we have the true and false labels as class0 class0
# false rows of col  9  of index  573
# True rows of col  5 of index  1147
# Base case for index  2294  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.8500000000000005 we have the true and false labels as class1 class1
# false rows of col  5  of index  1147
# Base case for index  2295  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.550000000000001 we have the true and false labels as class0 class1
# false rows of col  5  of index  143
# True rows of col  7 of index  287
# True rows of col  5 of index  574
# True rows of col  2 of index  1148
# Base case for index  2296  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.29000000000000004 we have the true and false labels as class0 class1
# false rows of col  2  of index  1148
# Base case for index  2297  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.6 we have the true and false labels as class0 class0
# false rows of col  5  of index  574
# Base case for index  1149  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.033333333333332 we have the true and false labels as class1 class1
# false rows of col  7  of index  287
# True rows of col  2 of index  575
# Base case for index  1150  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.433333333333334 we have the true and false labels as class0 class0
# false rows of col  2  of index  575
# Base case for index  1151  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.15 we have the true and false labels as class1 class0
# false rows of col  10  of index  4
# True rows of col  5 of index  9
# True rows of col  3 of index  18
# True rows of col  1 of index  36
# True rows of col  5 of index  72
# True rows of col  10 of index  144
# True rows of col  3 of index  288
# Base case for index  576  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.466666666666666 we have the true and false labels as class1 class1
# false rows of col  3  of index  288
# True rows of col  4 of index  577
# Base case for index  1154  column  10
# <class 'str'>
# <class 'str'>
# For column  10  with value 12.26 we have the true and false labels as class0 class1
# false rows of col  4  of index  577
# Base case for index  1155  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 6.5 we have the true and false labels as class0 None
# false rows of col  10  of index  144
# Base case for index  289  column  6
# <class 'str'>
# <class 'str'>
# For column  6  with value 156.6 we have the true and false labels as class0 class1
# false rows of col  5  of index  72
# True rows of col  8 of index  145
# True rows of col  4 of index  290
# True rows of col  8 of index  580
# Base case for index  1160  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 34.0 we have the true and false labels as class1 class0
# false rows of col  8  of index  580
# True rows of col  0 of index  1161
# Base case for index  2322  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.35000000000000003 we have the true and false labels as class1 class0
# false rows of col  0  of index  1161
# Base case for index  2323  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.6499999999999995 we have the true and false labels as class1 class1
# false rows of col  4  of index  290
# Base case for index  581  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.1 we have the true and false labels as class1 class1
# false rows of col  8  of index  145
# True rows of col  9 of index  291
# Base case for index  582  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.305 we have the true and false labels as class0 class1
# false rows of col  9  of index  291
# True rows of col  6 of index  583
# Base case for index  1166  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.1 we have the true and false labels as class1 class1
# false rows of col  6  of index  583
# Base case for index  1167  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.29 we have the true and false labels as class1 class0
# false rows of col  1  of index  36
# True rows of col  7 of index  73
# True rows of col  1 of index  146
# True rows of col  1 of index  292
# True rows of col  6 of index  584
# Base case for index  1168  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.25 we have the true and false labels as class0 class1
# false rows of col  6  of index  584
# Base case for index  1169  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.766666666666666 we have the true and false labels as class0 class0
# false rows of col  1  of index  292
# Base case for index  585  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.7 we have the true and false labels as class1 class0
# false rows of col  1  of index  146
# True rows of col  5 of index  293
# True rows of col  1 of index  586
# Base case for index  1172  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.833333333333333 we have the true and false labels as class1 class1
# false rows of col  1  of index  586
# Base case for index  1173  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.7 we have the true and false labels as class0 class1
# false rows of col  5  of index  293
# Base case for index  587  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.875 we have the true and false labels as class0 class0
# false rows of col  7  of index  73
# True rows of col  0 of index  147
# True rows of col  2 of index  294
# Base case for index  588  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.125 we have the true and false labels as class0 class0
# false rows of col  2  of index  294
# True rows of col  10 of index  589
# True rows of col  6 of index  1178
# Base case for index  2356  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 7.0 we have the true and false labels as class0 None
# false rows of col  6  of index  1178
# Base case for index  2357  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 36.25 we have the true and false labels as class1 class0
# false rows of col  10  of index  589
# Base case for index  1179  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.85 we have the true and false labels as class1 class1
# false rows of col  0  of index  147
# True rows of col  10 of index  295
# Base case for index  590  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.9 we have the true and false labels as class1 class1
# false rows of col  10  of index  295
# True rows of col  2 of index  591
# Base case for index  1182  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.133333333333333 we have the true and false labels as class1 class1
# false rows of col  2  of index  591
# Base case for index  1183  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 40.0 we have the true and false labels as class0 class1
# false rows of col  3  of index  18
# True rows of col  9 of index  37
# True rows of col  2 of index  74
# True rows of col  10 of index  148
# Base case for index  296  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 38.8 we have the true and false labels as class1 class0
# false rows of col  10  of index  148
# Base case for index  297  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.9875 we have the true and false labels as class0 class0
# false rows of col  2  of index  74
# True rows of col  8 of index  149
# True rows of col  0 of index  298
# Base case for index  596  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.344444444444445 we have the true and false labels as class1 class1
# false rows of col  0  of index  298
# True rows of col  5 of index  597
# Base case for index  1194  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.4 we have the true and false labels as class1 class1
# false rows of col  5  of index  597
# Base case for index  1195  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.325 we have the true and false labels as class0 class1
# false rows of col  8  of index  149
# True rows of col  0 of index  299
# True rows of col  5 of index  598
# Base case for index  1196  column  8
# <class 'str'>
# <class 'str'>
# For column  8  with value 3.128 we have the true and false labels as class0 class1
# false rows of col  5  of index  598
# True rows of col  0 of index  1197
# Base case for index  2394  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.1725 we have the true and false labels as class1 class0
# false rows of col  0  of index  1197
# Base case for index  2395  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.475 we have the true and false labels as class0 class0
# false rows of col  0  of index  299
# True rows of col  4 of index  599
# Base case for index  1198  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.75 we have the true and false labels as class1 class0
# false rows of col  4  of index  599
# Base case for index  1199  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.675000000000001 we have the true and false labels as class1 class1
# false rows of col  9  of index  37
# True rows of col  0 of index  75
# True rows of col  4 of index  150
# True rows of col  0 of index  300
# Base case for index  600  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.0 we have the true and false labels as class0 class0
# false rows of col  0  of index  300
# True rows of col  5 of index  601
# True rows of col  2 of index  1202
# Base case for index  2404  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.199999999999999 we have the true and false labels as class1 class0
# false rows of col  2  of index  1202
# Base case for index  2405  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.159999999999999 we have the true and false labels as class0 class0
# false rows of col  5  of index  601
# True rows of col  1 of index  1203
# Base case for index  2406  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.9 we have the true and false labels as class1 class1
# false rows of col  1  of index  1203
# Base case for index  2407  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.133333333333333 we have the true and false labels as class1 class0
# false rows of col  4  of index  150
# True rows of col  8 of index  301
# True rows of col  2 of index  602
# Base case for index  1204  column  3
# <class 'str'>
# <class 'str'>
# For column  3  with value 1.9 we have the true and false labels as class0 class1
# false rows of col  2  of index  602
# Base case for index  1205  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.160000000000001 we have the true and false labels as class1 class1
# false rows of col  8  of index  301
# True rows of col  0 of index  603
# True rows of col  7 of index  1206
# Base case for index  2412  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.566666666666666 we have the true and false labels as class1 class1
# false rows of col  7  of index  1206
# True rows of col  0 of index  2413
# Base case for index  4826  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 7.8 we have the true and false labels as class1 None
# false rows of col  0  of index  2413
# Base case for index  4827  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.5 we have the true and false labels as class0 class1
# false rows of col  0  of index  603
# Base case for index  1207  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.274 we have the true and false labels as class0 class1
# false rows of col  0  of index  75
# True rows of col  4 of index  151
# True rows of col  8 of index  302
# Base case for index  604  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.918181818181818 we have the true and false labels as class0 class0
# false rows of col  8  of index  302
# True rows of col  2 of index  605
# Base case for index  1210  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.3 we have the true and false labels as class0 class0
# false rows of col  2  of index  605
# Base case for index  1211  column  6
# <class 'str'>
# <class 'str'>
# For column  6  with value 131.75 we have the true and false labels as class1 class0
# false rows of col  4  of index  151
# True rows of col  9 of index  303
# True rows of col  1 of index  606
# Base case for index  1212  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.35 we have the true and false labels as class1 class1
# false rows of col  1  of index  606
# True rows of col  0 of index  1213
# Base case for index  2426  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.433333333333334 we have the true and false labels as class1 class0
# false rows of col  0  of index  1213
# Base case for index  2427  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.85 we have the true and false labels as class0 class0
# false rows of col  9  of index  303
# True rows of col  2 of index  607
# Base case for index  1214  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.142857142857143 we have the true and false labels as class0 class0
# false rows of col  2  of index  607
# Base case for index  1215  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.4925 we have the true and false labels as class0 class1
# false rows of col  5  of index  9
# True rows of col  5 of index  19
# True rows of col  8 of index  38
# True rows of col  9 of index  76
# True rows of col  10 of index  152
# True rows of col  4 of index  304
# True rows of col  1 of index  608
# True rows of col  1 of index  1216
# Base case for index  2432  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.3233333333333333 we have the true and false labels as class0 class1
# false rows of col  1  of index  1216
# Base case for index  2433  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 6.4 we have the true and false labels as class0 None
# false rows of col  1  of index  608
# Base case for index  1217  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.85 we have the true and false labels as class1 class1
# false rows of col  4  of index  304
# Base case for index  609  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.710000000000001 we have the true and false labels as class1 class1
# false rows of col  10  of index  152
# True rows of col  1 of index  305
# True rows of col  8 of index  610
# Base case for index  1220  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.6000000000000005 we have the true and false labels as class0 class0
# false rows of col  8  of index  610
# Base case for index  1221  column  9
# <class 'str'>
# <class 'str'>
# For column  9  with value 0.575 we have the true and false labels as class1 class0
# false rows of col  1  of index  305
# True rows of col  4 of index  611
# Base case for index  1222  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 6.4 we have the true and false labels as class0 None
# false rows of col  4  of index  611
# True rows of col  7 of index  1223
# Base case for index  2446  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.15 we have the true and false labels as class0 class1
# false rows of col  7  of index  1223
# Base case for index  2447  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.050000000000001 we have the true and false labels as class1 class1
# false rows of col  9  of index  76
# True rows of col  3 of index  153
# True rows of col  3 of index  306
# True rows of col  4 of index  612
# Base case for index  1224  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.4 we have the true and false labels as class1 class0
# false rows of col  4  of index  612
# Base case for index  1225  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.925000000000001 we have the true and false labels as class0 class0
# false rows of col  3  of index  306
# True rows of col  1 of index  613
# Base case for index  1226  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.014285714285713 we have the true and false labels as class1 class1
# false rows of col  1  of index  613
# Base case for index  1227  column  10
# <class 'str'>
# <class 'str'>
# For column  10  with value 11.940000000000001 we have the true and false labels as class1 class0
# false rows of col  3  of index  153
# True rows of col  3 of index  307
# True rows of col  1 of index  614
# Base case for index  1228  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.08 we have the true and false labels as class1 class0
# false rows of col  1  of index  614
# Base case for index  1229  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.333333333333333 we have the true and false labels as class0 class1
# false rows of col  3  of index  307
# True rows of col  3 of index  615
# True rows of col  4 of index  1230
# Base case for index  2460  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.6000000000000005 we have the true and false labels as class0 class0
# false rows of col  4  of index  1230
# Base case for index  2461  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 25.0 we have the true and false labels as class1 class0
# false rows of col  3  of index  615
# Base case for index  1231  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.55 we have the true and false labels as class0 class0
# false rows of col  8  of index  38
# True rows of col  2 of index  77
# True rows of col  0 of index  154
# True rows of col  0 of index  308
# Base case for index  616  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.133333333333333 we have the true and false labels as class0 class0
# false rows of col  0  of index  308
# True rows of col  1 of index  617
# Base case for index  1234  column  7
# <class 'str'>
# <class 'str'>
# For column  7  with value 0.9911249999999999 we have the true and false labels as class0 class1
# false rows of col  1  of index  617
# Base case for index  1235  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.333333333333333 we have the true and false labels as class0 class0
# false rows of col  0  of index  154
# True rows of col  5 of index  309
# True rows of col  1 of index  618
# Base case for index  1236  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.6000000000000005 we have the true and false labels as class1 class1
# false rows of col  1  of index  618
# True rows of col  8 of index  1237
# Base case for index  2474  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.4399999999999995 we have the true and false labels as class0 class0
# false rows of col  8  of index  1237
# Base case for index  2475  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.2 we have the true and false labels as class0 class1
# false rows of col  5  of index  309
# True rows of col  7 of index  619
# Base case for index  1238  column  7
# <class 'str'>
# <class 'str'>
# For column  7  with value 0.9905825 we have the true and false labels as class0 class1
# false rows of col  7  of index  619
# Base case for index  1239  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.4 we have the true and false labels as class1 class1
# false rows of col  2  of index  77
# True rows of col  0 of index  155
# True rows of col  4 of index  310
# True rows of col  1 of index  620
# True rows of col  0 of index  1240
# Base case for index  2480  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.7 we have the true and false labels as class0 class1
# false rows of col  0  of index  1240
# Base case for index  2481  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 7.1 we have the true and false labels as class0 None
# false rows of col  1  of index  620
# Base case for index  1241  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.633333333333333 we have the true and false labels as class0 class0
# false rows of col  4  of index  310
# True rows of col  0 of index  621
# Base case for index  1242  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.55 we have the true and false labels as class0 class0
# false rows of col  0  of index  621
# True rows of col  2 of index  1243
# Base case for index  2486  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.375 we have the true and false labels as class1 class1
# false rows of col  2  of index  1243
# Base case for index  2487  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.449999999999999 we have the true and false labels as class1 class0
# false rows of col  0  of index  155
# True rows of col  4 of index  311
# True rows of col  3 of index  622
# Base case for index  1244  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.459999999999999 we have the true and false labels as class0 class0
# false rows of col  3  of index  622
# True rows of col  4 of index  1245
# Base case for index  2490  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.7 we have the true and false labels as class1 class1
# false rows of col  4  of index  1245
# True rows of col  5 of index  2491
# Base case for index  4982  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.25 we have the true and false labels as class1 class0
# false rows of col  5  of index  2491
# Base case for index  4983  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.5 we have the true and false labels as class0 class0
# false rows of col  4  of index  311
# Base case for index  623  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.458333333333333 we have the true and false labels as class0 class0
# false rows of col  5  of index  19
# True rows of col  2 of index  39
# True rows of col  5 of index  78
# True rows of col  9 of index  156
# True rows of col  7 of index  312
# Base case for index  624  column  8
# <class 'str'>
# <class 'str'>
# For column  8  with value 3.122 we have the true and false labels as class1 class0
# false rows of col  7  of index  312
# Base case for index  625  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.242857142857143 we have the true and false labels as class0 class0
# false rows of col  9  of index  156
# True rows of col  9 of index  313
# True rows of col  2 of index  626
# Base case for index  1252  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.55 we have the true and false labels as class0 class1
# false rows of col  2  of index  626
# Base case for index  1253  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.8500000000000005 we have the true and false labels as class0 class0
# false rows of col  9  of index  313
# True rows of col  0 of index  627
# Base case for index  1254  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.8999999999999995 we have the true and false labels as class1 class1
# false rows of col  0  of index  627
# Base case for index  1255  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.75 we have the true and false labels as class0 class1
# false rows of col  5  of index  78
# True rows of col  3 of index  157
# True rows of col  0 of index  314
# Base case for index  628  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.2 we have the true and false labels as class0 class0
# false rows of col  0  of index  314
# Base case for index  629  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.699999999999999 we have the true and false labels as class0 class1
# false rows of col  3  of index  157
# Base case for index  315  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.127777777777778 we have the true and false labels as class0 class0
# false rows of col  2  of index  39
# True rows of col  9 of index  79
# True rows of col  3 of index  158
# True rows of col  5 of index  316
# Base case for index  632  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.4 we have the true and false labels as class1 class1
# false rows of col  5  of index  316
# Base case for index  633  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.27 we have the true and false labels as class0 class1
# false rows of col  3  of index  158
# True rows of col  9 of index  317
# Base case for index  634  column  8
# <class 'str'>
# <class 'str'>
# For column  8  with value 3.1983333333333337 we have the true and false labels as class1 class0
# false rows of col  9  of index  317
# Base case for index  635  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.875 we have the true and false labels as class0 class0
# false rows of col  9  of index  79
# True rows of col  7 of index  159
# Base case for index  318  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.157894736842105 we have the true and false labels as class0 class0
# false rows of col  7  of index  159
# True rows of col  0 of index  319
# True rows of col  7 of index  638
# Base case for index  1276  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.12 we have the true and false labels as class0 class0
# false rows of col  7  of index  638
# Base case for index  1277  column  9
# <class 'str'>
# <class 'str'>
# For column  9  with value 0.366 we have the true and false labels as class1 class0
# false rows of col  0  of index  319
# True rows of col  3 of index  639
# Base case for index  1278  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.133333333333333 we have the true and false labels as class1 class1
# false rows of col  3  of index  639
# True rows of col  0 of index  1279
# Base case for index  2558  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.3500000000000005 we have the true and false labels as class0 class0
# false rows of col  0  of index  1279
# Base case for index  2559  column  3
# <class 'str'>
# <class 'str'>
# For column  3  with value 1.4875 we have the true and false labels as class1 class0
# false rows of col  10  of index  2
# True rows of col  4 of index  5
# True rows of col  5 of index  10
# True rows of col  2 of index  20
# True rows of col  1 of index  40
# True rows of col  3 of index  80
# True rows of col  7 of index  160
# True rows of col  8 of index  320
# Base case for index  640  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.466666666666666 we have the true and false labels as class0 class1
# false rows of col  8  of index  320
# Base case for index  641  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.016666666666667 we have the true and false labels as class0 class0
# false rows of col  7  of index  160
# True rows of col  1 of index  321
# Base case for index  642  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.6000000000000005 we have the true and false labels as class1 class1
# false rows of col  1  of index  321
# True rows of col  0 of index  643
# Base case for index  1286  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.6 we have the true and false labels as class0 class1
# false rows of col  0  of index  643
# Base case for index  1287  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.766666666666667 we have the true and false labels as class0 class0
# false rows of col  3  of index  80
# True rows of col  8 of index  161
# True rows of col  4 of index  322
# Base case for index  644  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.666666666666667 we have the true and false labels as class0 class0
# false rows of col  4  of index  322
# True rows of col  3 of index  645
# Base case for index  1290  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.733333333333333 we have the true and false labels as class0 class0
# false rows of col  3  of index  645
# True rows of col  1 of index  1291
# Base case for index  2582  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.0 we have the true and false labels as class1 class0
# false rows of col  1  of index  1291
# Base case for index  2583  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.25 we have the true and false labels as class1 class1
# false rows of col  8  of index  161
# Base case for index  323  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.253846153846154 we have the true and false labels as class0 class0
# false rows of col  1  of index  40
# True rows of col  10 of index  81
# True rows of col  5 of index  162
# True rows of col  3 of index  324
# Base case for index  648  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 65.25 we have the true and false labels as class1 class0
# false rows of col  3  of index  324
# Base case for index  649  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.472222222222222 we have the true and false labels as class1 class1
# false rows of col  5  of index  162
# True rows of col  10 of index  325
# True rows of col  0 of index  650
# True rows of col  1 of index  1300
# Base case for index  2600  column  4
# <class 'str'>
# <class 'str'>
# For column  4  with value 0.0445 we have the true and false labels as class0 class1
# false rows of col  1  of index  1300
# Base case for index  2601  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 7.6 we have the true and false labels as class0 None
# false rows of col  0  of index  650
# Base case for index  1301  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.433333333333334 we have the true and false labels as class1 class1
# false rows of col  10  of index  325
# Base case for index  651  column  10
# <class 'str'>
# <class 'str'>
# For column  10  with value 11.149999999999999 we have the true and false labels as class1 class0
# false rows of col  10  of index  81
# True rows of col  8 of index  163
# True rows of col  0 of index  326
# Base case for index  652  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.46749999999999997 we have the true and false labels as class0 class1
# ...
# <class 'str'>
# <class 'str'>
# For column  3  with value 6.1 we have the true and false labels as class1 class0
# false rows of col  2  of index  249
# True rows of col  1 of index  499
# Base case for index  998  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.68 we have the true and false labels as class1 class1
# false rows of col  1  of index  499
# True rows of col  3 of index  999
# Base case for index  1998  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.333333333333333 we have the true and false labels as class0 class1
# false rows of col  3  of index  999
# Base case for index  1999  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.9 we have the true and false labels as class0 class0
# false rows of col  6  of index  62
# True rows of col  5 of index  125
# True rows of col  1 of index  250
# True rows of col  9 of index  500
# Base case for index  1000  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.990909090909091 we have the true and false labels as class1 class1
# false rows of col  9  of index  500
# True rows of col  9 of index  1001
# True rows of col  9 of index  2002
# Base case for index  4004  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.550000000000001 we have the true and false labels as class1 class0
# false rows of col  9  of index  2002
# Base case for index  4005  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.68 we have the true and false labels as class1 class1
# false rows of col  9  of index  1001
# True rows of col  0 of index  2003
# Base case for index  4006  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.75 we have the true and false labels as class1 class0
# false rows of col  0  of index  2003
# Base case for index  4007  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.233333333333334 we have the true and false labels as class0 class0
# false rows of col  1  of index  250
# True rows of col  3 of index  501
# True rows of col  10 of index  1002
# Base case for index  2004  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.533333333333334 we have the true and false labels as class1 class1
# false rows of col  10  of index  1002
# Base case for index  2005  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.5 we have the true and false labels as class1 class0
# false rows of col  3  of index  501
# True rows of col  9 of index  1003
# True rows of col  0 of index  2006
# True rows of col  0 of index  4012
# Base case for index  8024  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.35 we have the true and false labels as class1 class0
# false rows of col  0  of index  4012
# Base case for index  8025  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 7.2 we have the true and false labels as class0 None
# false rows of col  0  of index  2006
# Base case for index  4013  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 6.7 we have the true and false labels as class1 None
# false rows of col  9  of index  1003
# Base case for index  2007  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.266666666666667 we have the true and false labels as class0 class0
# false rows of col  5  of index  125
# True rows of col  6 of index  251
# True rows of col  0 of index  502
# True rows of col  2 of index  1004
# Base case for index  2008  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.7 we have the true and false labels as class0 class0
# false rows of col  2  of index  1004
# Base case for index  2009  column  1
# <class 'str'>
# <class 'str'>
# For column  1  with value 0.17333333333333334 we have the true and false labels as class1 class0
# false rows of col  0  of index  502
# Base case for index  1005  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.650000000000001 we have the true and false labels as class0 class0
# false rows of col  6  of index  251
# True rows of col  8 of index  503
# True rows of col  7 of index  1006
# Base case for index  2012  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.300000000000001 we have the true and false labels as class0 class0
# false rows of col  7  of index  1006
# True rows of col  0 of index  2013
# Base case for index  4026  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.3 we have the true and false labels as class1 class1
# false rows of col  0  of index  2013
# Base case for index  4027  column  8
# <class 'str'>
# <class 'str'>
# For column  8  with value 3.403333333333333 we have the true and false labels as class1 class0
# false rows of col  8  of index  503
# True rows of col  3 of index  1007
# True rows of col  1 of index  2014
# Base case for index  4028  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.85 we have the true and false labels as class0 class1
# false rows of col  1  of index  2014
# Base case for index  4029  column  0
# <class 'NoneType'>
# <class 'str'>
# For column  0  with value 8.6 we have the true and false labels as class0 None
# false rows of col  3  of index  1007
# Base case for index  2015  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.071428571428571 we have the true and false labels as class0 class0
# false rows of col  9  of index  31
# True rows of col  10 of index  63
# True rows of col  3 of index  126
# True rows of col  4 of index  252
# True rows of col  9 of index  504
# True rows of col  6 of index  1008
# True rows of col  2 of index  2016
# Base case for index  4032  column  2
# <class 'str'>
# <class 'str'>
# For column  2  with value 0.5299999999999999 we have the true and false labels as class1 class0
# false rows of col  2  of index  2016
# Base case for index  4033  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.728571428571428 we have the true and false labels as class0 class0
# false rows of col  6  of index  1008
# True rows of col  2 of index  2017
# Base case for index  4034  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.7 we have the true and false labels as class0 class0
# false rows of col  2  of index  2017
# Base case for index  4035  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 27.8 we have the true and false labels as class1 class0
# false rows of col  9  of index  504
# Base case for index  1009  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.874999999999999 we have the true and false labels as class0 class0
# false rows of col  4  of index  252
# True rows of col  6 of index  505
# True rows of col  7 of index  1010
# Base case for index  2020  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.225 we have the true and false labels as class0 class1
# false rows of col  7  of index  1010
# Base case for index  2021  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.683333333333334 we have the true and false labels as class0 class0
# false rows of col  6  of index  505
# True rows of col  3 of index  1011
# Base case for index  2022  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.666666666666668 we have the true and false labels as class1 class1
# false rows of col  3  of index  1011
# True rows of col  2 of index  2023
# Base case for index  4046  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.6499999999999995 we have the true and false labels as class0 class0
# false rows of col  2  of index  2023
# Base case for index  4047  column  6
# <class 'str'>
# <class 'str'>
# For column  6  with value 111.0 we have the true and false labels as class0 class1
# false rows of col  3  of index  126
# True rows of col  4 of index  253
# True rows of col  2 of index  506
# True rows of col  8 of index  1012
# Base case for index  2024  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.25 we have the true and false labels as class0 class0
# false rows of col  8  of index  1012
# True rows of col  2 of index  2025
# Base case for index  4050  column  3
# <class 'str'>
# <class 'str'>
# For column  3  with value 1.52 we have the true and false labels as class0 class1
# false rows of col  2  of index  2025
# True rows of col  1 of index  4051
# Base case for index  8102  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.640000000000001 we have the true and false labels as class0 class0
# false rows of col  1  of index  4051
# Base case for index  8103  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.033333333333333 we have the true and false labels as class0 class1
# false rows of col  2  of index  506
# True rows of col  0 of index  1013
# True rows of col  4 of index  2026
# Base case for index  4052  column  7
# <class 'str'>
# <class 'str'>
# For column  7  with value 0.9936119999999999 we have the true and false labels as class0 class1
# false rows of col  4  of index  2026
# Base case for index  4053  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.85 we have the true and false labels as class0 class0
# false rows of col  0  of index  1013
# Base case for index  2027  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.8999999999999995 we have the true and false labels as class0 class0
# false rows of col  4  of index  253
# True rows of col  10 of index  507
# True rows of col  6 of index  1014
# Base case for index  2028  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.3875 we have the true and false labels as class0 class0
# false rows of col  6  of index  1014
# True rows of col  0 of index  2029
# Base case for index  4058  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.433333333333334 we have the true and false labels as class0 class0
# false rows of col  0  of index  2029
# Base case for index  4059  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.433333333333334 we have the true and false labels as class1 class0
# false rows of col  10  of index  507
# Base case for index  1015  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.936842105263159 we have the true and false labels as class0 class0
# false rows of col  10  of index  63
# True rows of col  10 of index  127
# True rows of col  8 of index  254
# True rows of col  2 of index  508
# True rows of col  2 of index  1016
# Base case for index  2032  column  4
# <class 'str'>
# <class 'str'>
# For column  4  with value 0.043666666666666666 we have the true and false labels as class0 class1
# false rows of col  2  of index  1016
# True rows of col  2 of index  2033
# Base case for index  4066  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.75 we have the true and false labels as class0 class0
# false rows of col  2  of index  2033
# Base case for index  4067  column  5
# <class 'str'>
# <class 'str'>
# For column  5  with value 28.6 we have the true and false labels as class1 class0
# false rows of col  2  of index  508
# Base case for index  1017  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 5.840000000000001 we have the true and false labels as class0 class0
# false rows of col  8  of index  254
# True rows of col  0 of index  509
# True rows of col  5 of index  1018
# Base case for index  2036  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 7.520000000000001 we have the true and false labels as class0 class0
# false rows of col  5  of index  1018
# True rows of col  1 of index  2037
# Base case for index  4074  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.25 we have the true and false labels as class0 class1
# false rows of col  1  of index  2037
# Base case for index  4075  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 8.925 we have the true and false labels as class0 class0
# false rows of col  0  of index  509
# Base case for index  1019  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.744444444444445 we have the true and false labels as class0 class0
# false rows of col  10  of index  127
# Base case for index  255  column  0
# <class 'str'>
# <class 'str'>
# For column  0  with value 6.818421052631578 we have the true and false labels as class0 class0
# {128: [4, 0.031799999999999995, {'true_rows': ('class1', 'class1'), 'false_rows': ('class1', 'class0')}], 258: [3, 2.9000000000000004, {'true_rows': ('class1', 'class0'), 'false_rows': ('class0', 'class0')}], 518: [2, 0.29875000000000007, {'true_rows': ('class1', 'class1'), 'false_rows': ('class1', 'class0')}], 1039: [0, 6.6625, {'true_rows': ('class1', 'class0'), 'false_rows': ('class1', 'class1')}], 519: [8, 3.2524999999999995, {'true_rows': ('class0', 'class0'), 'false_rows': 1039}], 259: [8, 3.3045, {'true_rows': 518, 'false_rows': 519}], 129: [2, 0.3469230769230769, {'true_rows': 258, 'false_rows': 259}], 64: [1, 0.33138888888888896, {'true_rows': 128, 'false_rows': 129}], 520: [1, 0.3825, {'true_rows': ('class1', 'class0'), 'false_rows': ('class0', 'class0')}], 260: [0, 6.4, {'true_rows': 520, 'false_rows': ('class1', 'class1')}], 130: [8, 3.1542857142857144, {'true_rows': 260, 'false_rows': ('class1', 'class1')}], 525: [0, 6.375, {'true_rows': ('class1', 'class1'), 'false_rows': ('class1', 'class0')}], 262: [6, 106.5, {'true_rows': ('class1', 'class1'), 'false_rows': 525}], 131: [2, 0.3064, {'true_rows': 262, 'false_rows': ('class1', 'class1')}], 65: [6, 114.43589743589743, {'true_rows': 130, 'false_rows': 131}], 32: [8, 3.2278666666666664, {'true_rows': 64, 'false_rows': 65}], 2118: [0, 6.35, {'true_rows': ('class1', 'class0'), 'false_rows': ('class0', None)}], 1059: [7, 0.989626, {'true_rows': 2118, 'false_rows': ('class1', 'class1')}], 529: [2, 0.40545454545454546, {'true_rows': ('class0', None), 'false_rows': 1059}], 264: [7, 0.9906586666666667, {'true_rows': ('class1', 'class1'), 'false_rows': 529}], 265: [4, 0.0387, {'true_rows': ('class0', 'class0'), 'false_rows': ('class0', 'class1')}], 132: [9, 0.384, {'true_rows': 264, 'false_rows': 265}], 532: [0, 6.675000000000001, {'true_rows': ('class1', 'class1'), 'false_rows': ('class0', 'class1')}], 266: [2, 0.3241176470588235, {'true_rows': 532, 'false_rows': ('class1', 'class1')}], 133: [9, 0.37666666666666665, {'true_rows': 266, 'false_rows': ('class1', 'class1')}], 66: [4, 0.034846153846153846, {'true_rows': 132, 'false_rows': 133}], 268: [4, 0.041666666666666664, {'true_rows': ('class0', 'class0'), 'false_rows': ('class0', 'class1')}], 134: [6, 111.25, {'true_rows': 268, 'false_rows': ('class1', 'class1')}], 1081: [0, 7.199999999999999, {'true_rows': ('class0', 'class1'), 'false_rows': ('class1', None)}], 540: [0, 7.42, {'true_rows': ('class0', 'class0'), 'false_rows': 1081}], 541: [1, 0.23090909090909092, {'true_rows': ('class0', 'class0'), 'false_rows': ('class0', 'class1')}], 270: [0, 6.961904761904761, {'true_rows': 540, 'false_rows': 541}], 1084: [0, 6.374999999999999, {'true_rows': ('class1', 'class0'), 'false_rows': ('class0', 'class0')}], 542: [2, 0.32636363636363636, {'true_rows': 1084, 'false_rows': ('class1', 'class1')}], 543: [3, 1.8111111111111111, {'true_rows': ('class1', 'class0'), 'false_rows': ('class0', 'class0')}], 271: [0, 6.090000000000001, {'true_rows': 542, 'false_rows': 543}], 135: [7, 0.9891845121951219, {'true_rows': 270, 'false_rows': 271}], 67: [3, 3.1710526315789473, {'true_rows': 134, 'false_rows': 135}], 33: [6, 126.33944954128441, {'true_rows': 66, 'false_rows': 67}], 16: [9, 0.4663586956521739, {'true_rows': 32, 'false_rows': 33}], 273: [8, 3.2076923076923074, {'true_rows': ('class1', 'class1'), 'false_rows': ('class1', 'class0')}], 136: [1, 0.3386, {'true_rows': ('class1', 'class1'), 'false_rows': 273}], 274: [3, 7.068181818181817, {'true_rows': ('class0', 'class0'), 'false_rows': ('class0', 'class1')}], 275: [0, 6.354545454545455, {'true_rows': ('class1', 'class1'), 'false_rows': ('class1', 'class0')}], 137: [7, 0.9907727272727275, {'true_rows': 274, 'false_rows': 275}], 68: [2, 0.312340425531915, {'true_rows': 136, 'false_rows': 137}], 552: [3, 2.516666666666667, {'true_rows': ('class0', 'class0'), 'false_rows': ('class0', 'class1')}], 276: [5, 25.8, {'true_rows': 552, 'false_rows': ('class1', 'class1')}], 138: [3, 2.114285714285 ...
